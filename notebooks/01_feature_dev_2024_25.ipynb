# %%
import sys
from pathlib import Path

import pandas as pd

# Projekt-Root (eine Ebene über notebooks/)
root = Path("..").resolve()
if str(root) not in sys.path:
    sys.path.append(str(root))

root
# Out:
# /Users/stefanhofmann/Documents/Bewerbung/Portfolio/player_score

# %%
from src.pipeline import load_raw_for_scoring

season = "2024-2025"
raw_dir = root / "Data" / "Raw"

df_light = load_raw_for_scoring(season, raw_dir)
df_light.head()

# %%
df_light.info()
df_light.describe(numeric_only=True).T.head(20)
df_light["Pos"].value_counts().head(20)

# %%
from src.pipeline import build_feature_table

df_features = build_feature_table(season, raw_dir)
df_features.head()
