# %%
import sys
from pathlib import Path
import pandas as pd

# Projekt-Root (eine Ebene über notebooks/)
root = Path("..").resolve()
if str(root) not in sys.path:
    sys.path.append(str(root))

root
# Out:
# PosixPath('/Users/stefanhofmann/Documents/Bewerbung/Portfolio/player_score')

# %%
import pandas as pd
from pathlib import Path

root = Path("..").resolve()
csv_path = root / "Data" / "Processed" / "player_scores-2025-2026.csv"

df_all_scores = pd.read_csv(csv_path)
df_all_scores.head()
# Out:
#              Player         Squad                Comp Pos   Min   90s  \
# 0  Brenden Aaronson  Leeds United  eng Premier League  FW   711   7.9
# 1     Himad Abdelli        Angers          fr Ligue 1  MF   618   6.9
# 2   Laurent Abergel       Lorient          fr Ligue 1  MF  1036  11.5
# 3    Matthis Abline        Nantes          fr Ligue 1  FW   888   9.9
# 4             Abner          Lyon          fr Ligue 1  DF   450   5.0
#
#    OffScore_abs               OffBand  MidScore_abs               MidBand  \
# 0    256.412789  Solider Kaderspieler           NaN                   NaN
# 1           NaN                   NaN    373.140097  Solider Kaderspieler
# 2           NaN                   NaN    273.797101  Solider Kaderspieler
# 3    328.980172  Solider Kaderspieler           NaN                   NaN
# 4           NaN                   NaN           NaN                   NaN
#
#    DefScore_abs               DefBand
# 0           NaN                   NaN
# ...

# %%
df_all_scores[df_all_scores["Player"] == "Jude Bellingham"]
# Out:
#               Player        Squad        Comp     Pos  Min  90s  OffScore_abs  \
# 102  Jude Bellingham  Real Madrid  es La Liga  Off_MF  472  5.2    515.227164
#
#               OffBand  MidScore_abs MidBand  DefScore_abs DefBand
# 102  Top-Stammspieler           NaN     NaN           NaN     NaN
